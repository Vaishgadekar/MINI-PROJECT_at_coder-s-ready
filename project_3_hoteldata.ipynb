# %% [markdown]
# # <span style ='color:red'> HOTEL BOOKINGS DATA EXPOLORATION</span>

# %% [markdown]
# ![WhatsApp%20Image%202023-02-17%20at%203.29.04%20PM.jpeg](attachment:WhatsApp%20Image%202023-02-17%20at%203.29.04%20PM.jpeg)

# %% [markdown]
# ### <span style ='color:red'>importing important libreies</span>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### <span style ='color:red'>importing file </span>

# %%
data = pd.read_csv('C:/Users/Rushi/Desktop/Mini Project3/hotel_bookings.csv')

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data.info()           #what type of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data.isnull().sum()  #finding null values
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# #### <span style ='color:red'> in 3 type of data there is null values </span>
#  country =488
#  agent = 16340
#  company = 112593
#
#  this value is not required for the EDA

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### <span style ='color:red'>sorting of data</span>

# %%
data['hotel'].unique()      #how many type of data
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %% [markdown]
# ### <span style ='color:red'>two type of data in hotel ,that is resort and city hotel</span>
# - now we work on this data and find conclusion

# %%
data['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %% [raw]
# here we got the no of intries of city hotel and resort hotel

# %%
d1 = data[data['hotel'] == 'Resort Hotel']

# %%
d1
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
data.describe()        #statistic description
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [raw]
# droping company cloumn because it is not usefule in EDA

# %%
data.drop('company',axis=1, inplace=True)

# %%
data[['company']]    #shoeing error because comapny value is not present
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 data[['company']]
#
# File ~\.conda\envs\datascience\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.conda\envs\datascience\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
# ...

# %% [markdown]
# ### <span style ='color:red'>we perfrom eda on arrival data month </span>
# -in that we exactly get the time or period when most of the pepole come in hotel

# %%
data['arrival_date_month'].value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# <span style ='color:red'>we got all 12 month data when pepole visit hotel and there count</span>

# %%
data['arrival_date_month'].value_counts().sort_values(ascending=False).head()
# Out:
# August     13877
# July       12661
# May        11791
# October    11160
# April      11089
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# ### <span style ='color:red'>obsevation :</span>
# in month of august maximum pepole are come to visit the hotel and there count is 13877
# -also we got maximun booking five month

# %%
data.groupby('hotel').agg(np.mean)
# Out:
#               is_canceled   lead_time  arrival_date_year  \
# hotel
# City Hotel       0.417270  109.735724        2016.174285
# Resort Hotel     0.277634   92.675686        2016.121443
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                   27.177449                  15.786625
# Resort Hotel                 27.140864                  15.821243
#
#               stays_in_weekend_nights  stays_in_week_nights    adults  \
# hotel
# City Hotel                   0.795185              2.182957  1.850977
# Resort Hotel                 1.189815              3.128732  1.867149
#
#               children    babies  is_repeated_guest  previous_cancellations  \
# hotel
# City Hotel    0.091370  0.004941           0.025615                0.079743
# Resort Hotel  0.128682  0.013904           0.044383                0.101722
#
#               previous_bookings_not_canceled  booking_changes       agent  \
# hotel
# ...

# %% [raw]
# with 2 main quantity ie city hotel and resort hotel and we got mean of this 2 main quantity with respect to all parameter

# %% [markdown]
# ![WhatsApp%20Image%202023-02-17%20at%203.29.04%20PM%20%281%29.jpeg](attachment:WhatsApp%20Image%202023-02-17%20at%203.29.04%20PM%20%281%29.jpeg)

# %% [markdown]
# # <span style ='color:red'>conclusion :</span>

# %% [markdown]
# # <span style ='color:red'>august month is maximum hotel booking month </span>

# %% [markdown]
# # <span style ='color:red'> july ,may,octomber,april comes in decending order after the august</span>
